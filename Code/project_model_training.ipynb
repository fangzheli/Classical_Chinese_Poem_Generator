# %%
from transformers import BertTokenizer, GPT2LMHeadModel, TextGenerationPipeline, AdamW, get_linear_schedule_with_warmup

# %%
model = GPT2LMHeadModel.from_pretrained("./project_model_6")
tokenizer = BertTokenizer.from_pretrained("uer/gpt2-chinese-poem")
# model = GPT2LMHeadModel.from_pretrained("uer/gpt2-chinese-poem")
text_generator = TextGenerationPipeline(model, tokenizer)   
text_generator("[CLS]梅山如积翠，", max_length=40, do_sample=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': '[CLS]梅山如积翠， 日 出 林 影 稀 。 登 顿 出 涧 谷 ， 翛 然 清 我 衣 。 谷 口 闻 钟 磬 ， 月 明 烟 翠 微 。 易 遂'}]

# %%
result = text_generator("[CLS]梅山如积翠，", max_length=33, do_sample=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# test = test.sample(20)

# %%
# test1 = test

# %%
test
# Out:
#                                content
# 0             猛上临光殿，生擒归命侯。师心无学术，与子失贻谋。
# 1             送子目力短，朔风吹我裾。心焉独如结，子也当念予。
# 2             泽国登楼处，江船见月时。回书寄来使，多是客中诗。
# 3             芙蓉生石壁，云锦映青松。那忆南州路，归船处处逢。
# 4             叱起群龙驭，天鸡闻远空。东溟一杯水，洗出金轮红。
# ...                                ...
# 9971  避人忽起鸣衣桁，掠水飞来立钓矶。静处欲留看不足，翠光点破夕阳归。
# 9972  仙人喜作狡狯事，幻此溪声成雨声。我听以心非以耳，是溪是雨本分明。
# 9973  一竿潇洒玉玲珑，湘圃淇园在眼中。过客莫嫌枝叶少，才多枝叶便多风。
# 9974  薜萝垂户闭云烟，永谢区中未了缘。待得三秋明月夜，青松影里弄寒泉。
# 9975  裂麻已沮延龄相，抗疏能全陆贽生。为国重轻关一语，谁云七载噤无声。
#
# [9976 rows x 1 columns]

# %%
test.to_csv("test_unigram.csv")

# %%
import pandas as pd
test = pd.read_csv("evaluation_poem.csv")
test
# Out:
#     Unnamed: 0                           content  characters_num  \
# 0         2812          致虚本无功，辐辐自一毂。天根念正微，吾以观其复。               5
# 1         5829  滩声留客不容归，更尽西山一寸晖。要看冰轮升紫磨，绕枝寒鹊自惊飞。               7
# 2         8329  大患都缘有此身，笑看身外假为真。梦中更作西湖梦，谁谓先生不到闽。               7
# 3         6615  六月衡湘暑气蒸，幽香一喷冰人清。曾将移入浙西种，一岁才华一两茎。               7
# 4         8686  锦苞初擘露华红，掌上寒光映月空。玉女之浆不忍咽，当年太华事相同。               7
# 5          182          落落幽涧石，飘飘坠叶风。妾情无久暂，君去有西东。               5
# 6         2592          越公多美妓，卫尉足名姝。无计留红拂，伤心坠绿珠。               5
# 7         2796          窗外留书带，阶前卧绿枪。倦来抛素卷，狼藉满金床。               5
# 8         7207  永昼宫娥聚笑嬉，小王初习起居仪。朱衫御史心聪慧，学得中庭赞对词。               7
# 9         2800          童子请缨日，老夫黄屋来。楼船何自下，麋鹿至今哀。               5
# 10         935          水花分堑弱，山木抱云稠。更宿招提境，还同惠远游。               5
# 11        7807  白发萧萧礼部郎，风流不减贺知章。半生寒饿湖山里，八十重来坐玉堂。               7
# 12         323          杳杳河洲晚，客行殊未返。目随林鸟还，心共征鸿远。               5
# ...

# %%
test
# Out:
#                                content
# 0             猛上临光殿，生擒归命侯。师心无学术，与子失贻谋。
# 1             送子目力短，朔风吹我裾。心焉独如结，子也当念予。
# 2             泽国登楼处，江船见月时。回书寄来使，多是客中诗。
# 3             芙蓉生石壁，云锦映青松。那忆南州路，归船处处逢。
# 4             叱起群龙驭，天鸡闻远空。东溟一杯水，洗出金轮红。
# ...                                ...
# 9971  避人忽起鸣衣桁，掠水飞来立钓矶。静处欲留看不足，翠光点破夕阳归。
# 9972  仙人喜作狡狯事，幻此溪声成雨声。我听以心非以耳，是溪是雨本分明。
# 9973  一竿潇洒玉玲珑，湘圃淇园在眼中。过客莫嫌枝叶少，才多枝叶便多风。
# 9974  薜萝垂户闭云烟，永谢区中未了缘。待得三秋明月夜，青松影里弄寒泉。
# 9975  裂麻已沮延龄相，抗疏能全陆贽生。为国重轻关一语，谁云七载噤无声。
#
# [9976 rows x 1 columns]

# %%
test["characters_num"] = test['content'].apply(lambda x: x.find("，"))

# %%
test["first_sentence"] = test.apply(lambda x: x["content"][0:x["characters_num"] +1], axis=1)
test["origin_last_3"] = test.apply(lambda x: x["content"][x["characters_num"] +1:], axis=1)
test["generated_last_3"] = test.apply(generate, axis=1)
test["generated_content"] = test.apply(lambda x: x["first_sentence"]+x["generated_last_3"], axis=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
test['generated_evaluation'] = test["generated_last_3"].apply(lambda x: [c for c in x.replace("，","").replace("。","")])
test['origin_evaluation'] = test["origin_last_3"].apply(lambda x: [c for c in x.replace("，","").replace("。","")])
test["BLEU"] = test.apply(lambda x: bleu_1_score(x['origin_evaluation'], x['generated_evaluation']), axis=1)

# %%
test.BLEU.mean()
# Out:
# 0.06833350676404205

# %%
def generate(df):
    string = "[CLS]" + df.first_sentence
    max_length = 33
    if df.characters_num == 5:
        max_length = 25
    text_generator = TextGenerationPipeline(model, tokenizer)   
    result = text_generator(string, max_length=max_length, do_sample=True)[0]["generated_text"]
    result = result.replace(" ", "")
    return result[6+df.characters_num:]

# %%
import pandas as pd
from tqdm import tqdm, trange
import json
import pandas
def preprocess(file_name):
    with open(file_name, 'r', encoding="UTF-8") as f:
        Lines = f.readlines()
    contents = []
    for line in Lines:
        data = json.loads(line)
        content = data["content"]
        content = content.replace("|", "，", 1)
        content = content.replace("|", "。", 1)
        content = content.replace("|", "，", 1)
        content += "。"
        contents.append(content)
    poems = pd.DataFrame({"content":contents})
    return poems

# %%
train = preprocess('./Dataset/Datasets/CCPC/ccpc_train_v1.0.json')

# %%
test = preprocess('./Dataset/Datasets/CCPC/ccpc_test_v1.0.json')

# %%
import torch
from torch.utils.data import Dataset, DataLoader
class Poems(Dataset):   
    def __init__(self, series, truncate=False, max_length=32): 
 
        self.tokenizer = BertTokenizer.from_pretrained("uer/gpt2-chinese-poem") 
        self.poems = [] 
 
        for row in tqdm(series): 
          self.poems.append(torch.tensor( 
                self.tokenizer.encode(f"<|startoftext|>{row[:max_length]}<|endoftext|>") 
            ))                
        if truncate: 
            self.poems = self.poems[:20000] 
        self.poems_count = len(self.poems) 
 
    def __len__(self): 
        return self.poems_count 
 
    def __getitem__(self, item): 
        return self.poems[item] 
 
train_dataset = Poems(train['content'], truncate=False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 109727/109727 [00:46<00:00, 2360.44it/s]

# %%
tokenizer = BertTokenizer.from_pretrained("uer/gpt2-chinese-poem")
model = GPT2LMHeadModel.from_pretrained("uer/gpt2-chinese-poem")

# %%
def pack_tensor(new_tensor, packed_tensor, max_seq_len):
    if packed_tensor is None:
        return new_tensor, True, None
    if new_tensor.size()[1] + packed_tensor.size()[1] > max_seq_len:
        return packed_tensor, False, new_tensor
    else:
        packed_tensor = torch.cat([new_tensor, packed_tensor[:, 1:]], dim=1)
        return packed_tensor, True, None

# %%
def train(
    dataset, model, tokenizer,
    batch_size=16, epochs=2, lr=2e-5,
    max_seq_len=400, warmup_steps=200,
    gpt2_type="gpt2", output_dir=".", output_prefix="wreckgar",
    test_mode=False,save_model_on_epoch=False,
):
    acc_steps = 100
    device=torch.device("cuda")
    model = model.cuda()
    model.train()

    optimizer = AdamW(model.parameters(), lr=lr)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=warmup_steps, num_training_steps=-1
    )

    train_dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
    loss=0
    accumulating_batch_count = 0
    input_tensor = None

    for epoch in range(epochs):

        print(f"Training epoch {epoch}")
        print(loss)
        for idx, entry in tqdm(enumerate(train_dataloader)):
            (input_tensor, carry_on, remainder) = pack_tensor(entry, input_tensor, 768)

            if carry_on and idx != len(train_dataloader) - 1:
                continue

            input_tensor = input_tensor.to(device)
            outputs = model(input_tensor, labels=input_tensor)
            loss = outputs[0]
            loss.backward()

            if (accumulating_batch_count % batch_size) == 0:
                optimizer.step()
                scheduler.step()
                optimizer.zero_grad()
                model.zero_grad()

            accumulating_batch_count += 1
            input_tensor = None
        if save_model_on_epoch:
            torch.save(
                model.state_dict(),
                os.path.join(output_dir, f"{output_prefix}-{epoch}.pt"),
            )
    return model

# %%
model = train(train_dataset, model, tokenizer)

# %%
import os
os.makedirs("./model")
model.save_pretrained("./model")

# %%
from nltk.translate.bleu_score import sentence_bleu
def bleu_1_score(reference, candidate):
    score = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))
    # print(score)
    return score

# %%
3,4,8,9,10
